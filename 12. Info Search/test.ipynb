# %%
import pandas as pd

# %%
df = pd.read_csv('medium_articles.csv')
df
# Out:
#                                             title  \
# 0                             Mental Note Vol. 24
# 1                       Your Brain On Coronavirus
# 2                                  Mind Your Nose
# 3                        The 4 Purposes of Dreams
# 4                Surviving a Rod Through the Head
# ...                                           ...
# 192363        Why do you need a cleaning service?
# 192364  Daily cleaning and maintenance of bedding
# 192365        Beneficial Advice on Bond Cleaning!
# 192366    How I Learned Romanian in 37 Easy Steps
# 192367     Trying Pimsleur Cantonese in Hong Kong
#
#                                                      text  \
# 0       Photo by Josh Riemer on Unsplash\n\nMerry Chri...
# 1       Your Brain On Coronavirus\n\nA guide to the cu...
# 2       Mind Your Nose\n\nHow smell training can chang...
# 3       Passionate about the synergy between science a...
# 4       You’ve heard of him, haven’t you? Phineas Gage...
# ...

# %%
for elem in df.iloc[:5].iterrows():
    print(elem)
# Out:
# (0, title                                      Mental Note Vol. 24
# text         Photo by Josh Riemer on Unsplash\n\nMerry Chri...
# url          https://medium.com/invisible-illness/mental-no...
# authors                                           ['Ryan Fan']
# timestamp                     2020-12-26 03:38:10.479000+00:00
# tags         ['Mental Health', 'Health', 'Psychology', 'Sci...
# Name: 0, dtype: object)
# (1, title                                Your Brain On Coronavirus
# text         Your Brain On Coronavirus\n\nA guide to the cu...
# url          https://medium.com/age-of-awareness/how-the-pa...
# authors                                      ['Simon Spichak']
# timestamp                     2020-09-23 22:10:17.126000+00:00
# tags         ['Mental Health', 'Coronavirus', 'Science', 'P...
# Name: 1, dtype: object)
# (2, title                                           Mind Your Nose
# text         Mind Your Nose\n\nHow smell training can chang...
# ...
